# %%
import os
import pickle
import subprocess

from main import main

spindle_dim = 300
n_cone_facets = 600
n_parallel_facets = 20

max_time = 1200
sd_method = 'dual_simplex'
results_dir = 'results_spindle'
    
main(spindle=True, spindle_dim=spindle_dim, n_cone_facets=n_cone_facets, n_parallel_facets=n_parallel_facets,
     results_dir=results_dir, sd_method=sd_method)
# Out:
# Constructing spindle with dimension n=300, with 600 cone facets,and with 20 pairs of parallel facets
# Problem size: n = 300,  m_B = 1240,  m_A = 0
# Finding feasible solution...
# Building gurobi model for simplex...
# Feasible solution found with objective 0.0
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -300.070440737206
# Total solve time: 4.435770511627197
# Number of iterations: 1594.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.686199426651001
#
# Iteration 0
# Objective: 0.0
# Steepness: -3.208198687803844e-05
# Step length: 31546.62976337654
#
# Iteration 50
# Objective: -144.40154800117492
# Steepness: -2.832771467241828e-05
# Step length: 48799.20022996651
#
# Iteration 100
# Objective: -177.2322812402253
# ...

# %%
import os
import pickle
import subprocess

from main import main

n = 1500
k = 10

max_time = 1200
sd_method = 'dual_simplex'
results_dir = 'PP_results'
    
main(partition_polytope=True, n=n, k=k, max_time=max_time, results_dir=results_dir, sd_method=sd_method)
# Out:
# Constructing partition polytope with n=1500 and k=10
# Problem size: n = 15000,  m_B = 15020,  m_A = 1500
# Finding feasible solution...
# Building gurobi model for simplex...
# Feasible solution found with objective 736792.0
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 139101.0
# Total solve time: 0.4996943473815918
# Number of iterations: 4044.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 384.8500454425812
# Iteration 0
# Objective: 736792
# Steepness: -477.9285714285714
# Step length: 1
# Iteration 50
# Objective: 596731
# Steepness: -390.0
# Step length: 1
# Iteration 100
# Objective: 485524
# Steepness: -341.75
# Step length: 1
# Iteration 150
# Objective: 383633
# Steepness: -275.625
# Step length: 1
# Iteration 200
# Objective: 298343
# ...

# %%
import os
import pickle
import subprocess

from main import main

problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cre-c', 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'modszk1', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'pilot', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p']     

#problems = ['vtp_base', 'wood1p']
        
results_dir = 'results4'
problem_dir = 'test_problems'
max_time = 300
#mps_fns = os.listdir(problem_dir)
#skipped_inds = [1, 11, 18, 22, 27, 34, 35, 39, 40]

#start_ind = 73
#print(len(mps_fns))
#for i in range(start_ind, len(mps_fns)):
for i, problem in enumerate(problems):
    #mps_fn = mps_fns[i]
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i, len(problems), mps_fn))
    
    main(mps_fn, results_dir=results_dir, max_time=max_time)
# Out:
# Working on problem 0 of 80: test_problems\adlittle
# Reading test_problems\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238036
# Total solve time: 0.0
# Number of iterations: 100.0
#
# Solving with steepest descent...
# Building polyhedral model...
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.015621662139892578
#
# Iteration: 0
# alpha: 1.492387497139124
# steepness: -1093.3333333333335
#
# Iteration: 50
# alpha: 10.693037152657931
# steepness: -1.1566308634677105
# Total time for steepest-descent scheme: 0.0937654972076416
#
# Solution for adlittle using steepest-descent augmentation:
#
# Optimal objective: 225494.96316238018
# Total solve time: 0.0937654972076416
# Number of iterations: 61
# ...

# %%
import os
import pickle
import subprocess

from main import main

def execute(cmd):
    popen = subprocess.Popen(cmd, stdout=subprocess.PIPE, universal_newlines=True)
    for stdout_line in iter(popen.stdout.readline, ""):
        yield stdout_line 
    popen.stdout.close()
    return_code = popen.wait()
    if return_code:
        raise subprocess.CalledProcessError(return_code, cmd) 

problems = ['vtp_base', 'wood1p']
        
results_dir = 'results2'
problem_dir = 'test_problems'
max_time = 300
#mps_fns = os.listdir(problem_dir)

#skipped_inds = [1, 11, 18, 22, 27, 34, 35, 39, 40]

#start_ind = 73
#print(len(mps_fns))
#for i in range(start_ind, len(mps_fns)):
for i, problem in enumerate(problems):
    #mps_fn = mps_fns[i]
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i, len(problems), mps_fn))
    
    main(mps_fn, results_dir=results_dir, max_time=max_time)
    
    #cmd = ['python', 'main.py', '--mps_fn', mps_fn]
    #for x in execute(cmd):
    #    print(x, end='')   
    #subprocess.call(cmd)
# Out:
# Working on problem 0 of 2: test_problems\vtp_base
# Reading test_problems\vtp_base...
# Building polyhedron...
# Problem size: n = 203,  m_B = 392,  m_A = 73
# Finding feasible solution...
# Academic license - for non-commercial use only
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 129831.46246136134
# Total solve time: 0.0
# Number of iterations: 70.0
#
# Solving with steepest descent...
# Building polyhedral model...
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.09377193450927734
#
# Iteration: 0
# alpha: 10669.863
# steepness: -0.9718834253073354
# Total time for steepest-descent scheme: 0.12492680549621582
#
# Solution for vtp_base using steepest-descent augmentation:
#
# Optimal objective: 129831.4624613614
# Total solve time: 0.12492680549621582
# Number of iterations: 34
# First simplex iterations 223.0
# ...

# %%
import os
import pickle
import subprocess

from main import main

def execute(cmd):
    popen = subprocess.Popen(cmd, stdout=subprocess.PIPE, universal_newlines=True)
    for stdout_line in iter(popen.stdout.readline, ""):
        yield stdout_line 
    popen.stdout.close()
    return_code = popen.wait()
    if return_code:
        raise subprocess.CalledProcessError(return_code, cmd) 

problems = ['vtp_base', 'wood1p']
        
results_dir = 'results2'
problem_dir = 'test_problems'
max_time = 300
#mps_fns = os.listdir(problem_dir)

#skipped_inds = [1, 11, 18, 22, 27, 34, 35, 39, 40]

#start_ind = 73
#print(len(mps_fns))
#for i in range(start_ind, len(mps_fns)):
for i, problem in enumerate(problems):
    #mps_fn = mps_fns[i]
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i, len(problems), mps_fn))
    
    main(mps_fn, results_dir=results_dir, max_time=max_time)
    
    #cmd = ['python', 'main.py', '--mps_fn', mps_fn]
    #for x in execute(cmd):
    #    print(x, end='')   
    #subprocess.call(cmd)
# Out:
# Working on problem 0 of 2: test_problems\vtp_base
# Reading test_problems\vtp_base...
# Building polyhedron...
# Problem size: n = 203,  m_B = 392,  m_A = 73
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 129831.46246136134
# Total solve time: 0.0
# Number of iterations: 70.0
#
# Solving with steepest descent...
# Building polyhedral model...
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.062160491943359375
#
# Iteration: 0
# alpha: 10669.863
# steepness: -0.9718834253073354
#
# Iteration: 20
# alpha: 4419.863
# steepness: -0.9321245930020907
# Total time for steepest-descent scheme: 0.1405956745147705
#
# Solution for vtp_base using steepest-descent augmentation:
#
# Optimal objective: 129831.4624613614
# Total solve time: 0.1405956745147705
# Number of iterations: 34
# First simplex iterations 223.0
# ...

# %%
import os
import pickle
import subprocess

from main import main

def execute(cmd):
    popen = subprocess.Popen(cmd, stdout=subprocess.PIPE, universal_newlines=True)
    for stdout_line in iter(popen.stdout.readline, ""):
        yield stdout_line 
    popen.stdout.close()
    return_code = popen.wait()
    if return_code:
        raise subprocess.CalledProcessError(return_code, cmd)

problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cre-c', 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'modszk1', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'pilot', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p']     
        
results_dir = 'results2'
problem_dir = 'test_problems'
max_time = 300
#mps_fns = os.listdir(problem_dir)

#skipped_inds = [1, 11, 18, 22, 27, 34, 35, 39, 40]

#start_ind = 73
#print(len(mps_fns))
#for i in range(start_ind, len(mps_fns)):
for i, problem in enumerate(problems):
    #mps_fn = mps_fns[i]
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i, len(problems), mps_fn))
    
    main(mps_fn, results_dir=results_dir, max_time=max_time)
    
    #cmd = ['python', 'main.py', '--mps_fn', mps_fn]
    #for x in execute(cmd):
    #    print(x, end='')   
    #subprocess.call(cmd)
# Out:
# Working on problem 0 of 80: test_problems\adlittle
# Reading test_problems\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Academic license - for non-commercial use only
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238036
# Total solve time: 0.0
# Number of iterations: 100.0
#
#
#
# Working on problem 1 of 80: test_problems\afiro
# Reading test_problems\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -464.75314285714285
# Total solve time: 0.0
# Number of iterations: 11.0
#
#
#
# Working on problem 2 of 80: test_problems\agg2
# Reading test_problems\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# ...
