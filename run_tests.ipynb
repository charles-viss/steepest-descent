# %%
import os
import pickle
import subprocess

from main import main

def execute(cmd):
    popen = subprocess.Popen(cmd, stdout=subprocess.PIPE, universal_newlines=True)
    for stdout_line in iter(popen.stdout.readline, ""):
        yield stdout_line 
    popen.stdout.close()
    return_code = popen.wait()
    if return_code:
        raise subprocess.CalledProcessError(return_code, cmd)

results_dir = 'results'
problem_dir = 'test_problems'
max_time = 300
mps_fns = os.listdir(problem_dir)

skipped_inds = [1, 11, 18, 22, 27, 34, 35, 39, 40]

start_ind = 73
print(len(mps_fns))
for i in range(start_ind, len(mps_fns)):
    mps_fn = mps_fns[i]
    print('\n\n\nWorking on problem {}: {}'.format(i, mps_fn))
    
    main(mps_fn, results_dir=results_dir, max_time=max_time)
    
    #cmd = ['python', 'main.py', '--mps_fn', mps_fn]
    #for x in execute(cmd):
    #    print(x, end='')   
    #subprocess.call(cmd)
# Out:
# 112
#
#
#
# Working on problem 73: recipe
# Reading test_problems\recipe...
# Building polyhedron...
# Problem size: n = 180,  m_B = 247,  m_A = 93
# Finding feasible solution...
# Academic license - for non-commercial use only
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -266.61600000000027
# Total solve time: 0.0
# Number of iterations: 26.0
#
# Solving with steepest descent...
# Building polyhedral model...
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.04659008979797363
#
# Iteration: 0
# alpha: 100.0
# steepness: -0.19060000000000002
# Total time for steepest-descent scheme: 0.04686617851257324
#
# Solution for recipe using steepest-descent augmentation:
#
# Optimal objective: -266.616
# Total solve time: 0.04686617851257324
# Number of iterations: 11
# First simplex iterations 41.0
# Average num simplex iterations 5.666666666666667
# ...
