# %%
import os
import pickle
import subprocess

from main import main

problems = ['adlittle', 'afiro', 'agg2','agg3','agg', 'bandm',
 'beaconfd', 'blend', 'bnl1', 'boeing1', 'boeing2', 'bore3d', 'brandy', 'capri',
 'cre-c', 'cycle', 'degen2', 'degen3', 'e226', 'etamacro', 'fffff800', 'finnis',
 'fit1d', 'fit1p', 'forplan', 'ganges', 'gfrd-pnc', 'grow15', 'grow22', 'grow7',
 'israel', 'kb2', 'ken-07', 'lotfi', 'maros', 'modszk1', 'pds-02', 'perold',
 'pilot4', 'pilotnov', 'qap08', 'recipe', 'sc105', 'sc205', 'sc50a',
 'sc50b', 'scagr25', 'scagr7', 'scfxm1', 'scfxm2', 'scfxm3', 'scorpion', 'scrs8',
 'scsd1', 'scsd6', 'scsd8', 'sctap1', 'sctap2', 'sctap3', 'seba', 'share1b',
 'share2b', 'shell', 'ship04l', 'ship04s', 'ship08l', 'ship08s', 'ship12l', 'ship12s',
 'sierra', 'stair', 'standata', 'standgub', 'standmps', 'stocfor1', 'stocfor2', 'tuff',
 'vtp_base', 'wood1p']     
        
    
results_dir = 'results'
problem_dir = 'netlib_lp_subset'
max_time = 300
reset = False
sd_method = 'dual_simplex'

for i, problem in enumerate(problems):
    mps_fn = os.path.join(problem_dir, problem)
    print('\n\n\nWorking on problem {} of {}: {}'.format(i+1, len(problems), mps_fn))    
    main(mps_fn=mps_fn, results_dir=results_dir, max_time=max_time, reset=reset, sd_method=sd_method)
# Out:
# Working on problem 1 of 79: netlib_lp_subset\adlittle
# Reading netlib_lp_subset\adlittle...
# Building polyhedron...
# Problem size: n = 97,  m_B = 138,  m_A = 15
# Finding feasible solution...
# Academic license - for non-commercial use only
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 225494.96316238036
# Total solve time: 0.0
# Number of iterations: 100.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.015620231628417969
#
# Iteration 0
# Objective: 671734.1100278503
# Steepness: -1093.3333333333335
# Step length: 1.492387497139124
#
# Iteration 1
# Objective: 670102.4330309781
# Steepness: -608.695652173913
# Step length: 14.047128014198497
#
# Iteration 50
# Objective: 225785.31769628628
# Steepness: -1.1566308634677105
# Step length: 10.693037152657931
# Total time for steepest-descent scheme: 0.07810664176940918
#
# Solution for adlittle using steepest-descent augmentation:
#
# Optimal objective: 225494.96316238018
# Total solve time: 0.07810664176940918
# Number of iterations: 61
# First simplex iterations 22.0
# Average num simplex iterations 7.741935483870968
# Total simplex iterations: 480.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 2 of 79: netlib_lp_subset\afiro
# Reading netlib_lp_subset\afiro...
# Building polyhedron...
# Problem size: n = 32,  m_B = 51,  m_A = 8
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -464.75314285714285
# Total solve time: 0.0
# Number of iterations: 11.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.0
#
# Iteration 0
# Objective: 440.0
# Steepness: -3.333333333333334
# Step length: 131.99999999999997
#
# Iteration 1
# Objective: 7.105427357601002e-14
# Steepness: -0.14049832478346544
# Step length: 3245.3160714285714
# Total time for steepest-descent scheme: 0.0
#
# Solution for afiro using steepest-descent augmentation:
#
# Optimal objective: -464.7531428571429
# Total solve time: 0.0
# Number of iterations: 3
# First simplex iterations 10.0
# Average num simplex iterations 6.5
# Total simplex iterations: 26.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 3 of 79: netlib_lp_subset\agg2
# Reading netlib_lp_subset\agg2...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -20239252.35597712
# Total solve time: 0.0
# Number of iterations: 160.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.23432135581970215
#
# Iteration 0
# Objective: 109674378.8584193
# Steepness: -83.04516320666386
# Step length: 742.8174157224255
#
# Iteration 1
# Objective: 109612691.46489787
# Steepness: -58.894049681906935
# Step length: 2062.9421267070884
#
# Iteration 50
# Objective: -17099260.01317915
# Steepness: -1.14249624814369
# Step length: 623901.4590820029
# Total time for steepest-descent scheme: 0.49988245964050293
#
# Solution for agg2 using steepest-descent augmentation:
#
# Optimal objective: -20239252.35597711
# Total solve time: 0.49988245964050293
# Number of iterations: 98
# First simplex iterations 58.0
# Average num simplex iterations 13.98989898989899
# Total simplex iterations: 1385.0
# First solve time 0.015623092651367188
# Average solve time 0.000946661438604798
# Total solve time: 0.093719482421875
#
#
#
# Working on problem 4 of 79: netlib_lp_subset\agg3
# Reading netlib_lp_subset\agg3...
# Building polyhedron...
# Problem size: n = 302,  m_B = 758,  m_A = 60
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 10312115.935089217
# Total solve time: 0.0
# Number of iterations: 179.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.23432016372680664
#
# Iteration 0
# Objective: 959481192.9048736
# Steepness: -99.87397600792033
# Step length: 6779195.16351643
#
# Iteration 1
# Objective: 282416017.79082406
# Steepness: -98.91594197697769
# Step length: 2024737.8201427716
#
# Iteration 50
# Objective: 11701648.507671447
# Steepness: -1.0266135922886959
# Step length: 283882.384223927
# Total time for steepest-descent scheme: 0.43739867210388184
#
# Solution for agg3 using steepest-descent augmentation:
#
# Optimal objective: 10312115.934937906
# Total solve time: 0.43739867210388184
# Number of iterations: 90
# First simplex iterations 105.0
# Average num simplex iterations 14.571428571428571
# Total simplex iterations: 1326.0
# First solve time 0.0
# Average solve time 0.0020600413228129295
# Total solve time: 0.18746376037597656
#
#
#
# Working on problem 5 of 79: netlib_lp_subset\agg
# Reading netlib_lp_subset\agg...
# Building polyhedron...
# Problem size: n = 163,  m_B = 615,  m_A = 36
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -35991767.2865765
# Total solve time: 0.0
# Number of iterations: 73.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.12497210502624512
#
# Iteration 0
# Objective: 740291988.0422664
# Steepness: -99.956349594957
# Step length: 2593312.7308917483
#
# Iteration 1
# Objective: 481073914.1041981
# Steepness: -99.91025604320603
# Step length: 465768.3348672796
# Total time for steepest-descent scheme: 0.21869921684265137
#
# Solution for agg using steepest-descent augmentation:
#
# Optimal objective: -35991767.28657651
# Total solve time: 0.21869921684265137
# Number of iterations: 35
# First simplex iterations 94.0
# Average num simplex iterations 27.916666666666668
# Total simplex iterations: 1005.0
# First solve time 0.0
# Average solve time 0.00043392181396484375
# Total solve time: 0.015621185302734375
#
#
#
# Working on problem 6 of 79: netlib_lp_subset\bandm
# Reading netlib_lp_subset\bandm...
# Building polyhedron...
# Problem size: n = 472,  m_B = 472,  m_A = 305
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -158.62801845009076
# Total solve time: 0.0
# Number of iterations: 262.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.28806185722351074
#
# Iteration 0
# Objective: 87.26928871787423
# Steepness: -3.0233333333333334
# Step length: 5.4910125
#
# Iteration 1
# Objective: 70.66812759287424
# Steepness: -2.383094080529391
# Step length: 5.841682594697336
#
# Iteration 50
# Objective: -77.50713490284168
# Steepness: -0.15444312737653226
# Step length: 0.03231368007877465
#
# Iteration 100
# Objective: -142.78435768307412
# Steepness: -0.038105211978929535
# Step length: 0.6680054125224947
#
# Iteration 150
# Objective: -155.31817155951862
# Steepness: -0.009868996236555886
# Step length: 13.42801790487695
#
# Iteration 200
# Objective: -158.5402814972021
# Steepness: -0.0013724437525896355
# Step length: 3.7514832264718283
# Total time for steepest-descent scheme: 0.890416145324707
#
# Solution for bandm using steepest-descent augmentation:
#
# Optimal objective: -158.62801845012027
# Total solve time: 0.890416145324707
# Number of iterations: 213
# First simplex iterations 297.0
# Average num simplex iterations 25.700934579439252
# Total simplex iterations: 5500.0
# First solve time 0.015623092651367188
# Average solve time 0.0016061123286452248
# Total solve time: 0.3437080383300781
#
#
#
# Working on problem 7 of 79: netlib_lp_subset\beaconfd
# Reading netlib_lp_subset\beaconfd...
# Building polyhedron...
# Problem size: n = 262,  m_B = 295,  m_A = 140
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 33592.48580719999
# Total solve time: 0.015620708465576172
# Number of iterations: 20.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.08862495422363281
#
# Iteration 0
# Objective: 33992.2782842
# Steepness: -0.07985710632678573
# Step length: 1074.2533000000003
#
# Iteration 1
# Objective: 33906.4915242
# Steepness: -0.060300634412592896
# Step length: 10.890871063301617
# Total time for steepest-descent scheme: 0.06248617172241211
#
# Solution for beaconfd using steepest-descent augmentation:
#
# Optimal objective: 33592.485807200006
# Total solve time: 0.06248617172241211
# Number of iterations: 21
# First simplex iterations 85.0
# Average num simplex iterations 11.545454545454545
# Total simplex iterations: 254.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 8 of 79: netlib_lp_subset\blend
# Reading netlib_lp_subset\blend...
# Building polyhedron...
# Problem size: n = 83,  m_B = 114,  m_A = 43
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -30.812149845828237
# Total solve time: 0.0
# Number of iterations: 90.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.015620946884155273
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.07995096139551053
# Step length: 204.46220784365894
#
# Iteration 1
# Objective: -16.346950086149214
# Steepness: -0.07507855792833903
# Step length: 11.70043238845503
# Total time for steepest-descent scheme: 0.031245708465576172
#
# Solution for blend using steepest-descent augmentation:
#
# Optimal objective: -30.81214984582822
# Total solve time: 0.031245708465576172
# Number of iterations: 23
# First simplex iterations 72.0
# Average num simplex iterations 10.0
# Total simplex iterations: 240.0
# First solve time 0.0
# Average solve time 0.0
# Total solve time: 0.0
#
#
#
# Working on problem 9 of 79: netlib_lp_subset\bnl1
# Reading netlib_lp_subset\bnl1...
# removing redundant constraint 'R1001033'
# removing redundant constraint 'R1001034'
# removing redundant constraint 'R1001039'
# removing redundant constraint 'R1001084'
# removing redundant constraint 'R1002034'
# removing redundant constraint 'R1002084'
# removing redundant constraint 'R1003034'
# removing redundant constraint 'R1003084'
# removing redundant constraint 'R1004034'
# removing redundant constraint 'R1004084'
# removing redundant constraint 'HTGR3004'
# Building polyhedron...
# Problem size: n = 1175,  m_B = 1576,  m_A = 231
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1977.6295615228814
# Total solve time: 0.015621423721313477
# Number of iterations: 382.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 1.5127520561218262
#
# Iteration 0
# Objective: 2115.805905422868
# Steepness: -0.7838325324871562
# Step length: 4.856190808556726
#
# Iteration 1
# Objective: 2111.999465083156
# Steepness: -0.6354513698630138
# Step length: 2.99269911829352
#
# Iteration 50
# Objective: 2055.884030028922
# Steepness: -0.05364480322302411
# Step length: 20.131054147128204
#
# Iteration 100
# Objective: 2015.0391641604392
# Steepness: -0.015422201005307345
# Step length: 28.973252725990225
#
# Iteration 150
# Objective: 1988.1042867468595
# Steepness: -0.0063419619166046465
# Step length: 9.356949944868514
#
# Iteration 200
# Objective: 1977.6628741791296
# Steepness: -0.00019239710163952443
# Step length: 5.3395321294453595
# Total time for steepest-descent scheme: 2.160757064819336
#
# Solution for bnl1 using steepest-descent augmentation:
#
# Optimal objective: 1977.6295785086165
# Total solve time: 2.160757064819336
# Number of iterations: 203
# First simplex iterations 514.0
# Average num simplex iterations 23.083333333333332
# Total simplex iterations: 4709.0
# First solve time 0.025964736938476562
# Average solve time 0.0032819392634373086
# Total solve time: 0.6695156097412109
#
#
#
# Working on problem 10 of 79: netlib_lp_subset\boeing1
# Reading netlib_lp_subset\boeing1...
# removing redundant constraint 'ATONMILE'
# removing redundant constraint 'RTONMILE'
# removing redundant constraint 'LFTNMILE'
# Building polyhedron...
# Problem size: n = 384,  m_B = 968,  m_A = 9
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -335.21356750712687
# Total solve time: 0.015623331069946289
# Number of iterations: 516.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.34366703033447266
#
# Iteration 0
# Objective: 185.15514908540237
# Steepness: -0.04583250627946371
# Step length: 25.020530715655763
#
# Iteration 1
# Objective: 184.00839545426157
# Steepness: -0.04562063710694419
# Step length: 2.614579797855746
#
# Iteration 50
# Objective: 139.38482949927732
# Steepness: -0.011809188377272494
# Step length: 18.347500606060603
#
# Iteration 100
# Objective: 47.06307786969873
# Steepness: -0.007789914512578523
# Step length: 227.24706848818226
#
# Iteration 150
# Objective: -161.63177415631264
# Steepness: -0.005655640976492949
# Step length: 259.8114
#
# Iteration 200
# Objective: -280.9197082056158
# Steepness: -0.0032030293970960904
# Step length: 574.5138215698862
#
# Iteration 250
# Objective: -321.30718015133044
# Steepness: -0.0015857426175140826
# Step length: 796.2546934862265
#
# Iteration 300
# Objective: -329.77650922695307
# Steepness: -0.0007388385296760844
# Step length: 569.8821294785594
#
# Iteration 350
# Objective: -335.0285738430782
# Steepness: -6.382155434510293e-05
# Step length: 206.31524834276945
# Total time for steepest-descent scheme: 2.202610492706299
#
# Solution for boeing1 using steepest-descent augmentation:
#
# Optimal objective: -335.2136136239345
# Total solve time: 2.202610492706299
# Number of iterations: 363
# First simplex iterations 425.0
# Average num simplex iterations 14.615384615384615
# Total simplex iterations: 5320.0
# First solve time 0.015621185302734375
# Average solve time 0.0018453755221524081
# Total solve time: 0.6717166900634766
#
#
#
# Working on problem 11 of 79: netlib_lp_subset\boeing2
# Reading netlib_lp_subset\boeing2...
# removing redundant constraint 'LF1013B1'
# removing redundant constraint 'LF1013B2'
# removing redundant constraint 'LF1015B1'
# removing redundant constraint 'LF1017B1'
# removing redundant constraint 'LF1019B1'
# removing redundant constraint 'LF1019B2'
# removing redundant constraint 'LF1004B1'
# removing redundant constraint 'LF1008B1'
# removing redundant constraint 'LF1008B2'
# removing redundant constraint 'LF1010B1'
# removing redundant constraint 'LF1010B2'
# removing redundant constraint 'LF1010B3'
# removing redundant constraint 'LF1012B1'
# removing redundant constraint 'LF1014B1'
# removing redundant constraint 'LF1014B2'
# removing redundant constraint 'LF1100B1'
# removing redundant constraint 'LF1100B2'
# removing redundant constraint 'LF1100B3'
# removing redundant constraint 'LF1100B4'
# removing redundant constraint 'LF1100B5'
# removing redundant constraint 'LF1102B1'
# removing redundant constraint 'LF1102B2'
# removing redundant constraint 'LF1102B3'
# removing redundant constraint 'LF1102B4'
# removing redundant constraint 'LF1200B1'
# removing redundant constraint 'LF1201B1'
# Building polyhedron...
# Problem size: n = 143,  m_B = 352,  m_A = 4
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -315.01872801520284
# Total solve time: 0.0
# Number of iterations: 72.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.062485456466674805
#
# Iteration 0
# Objective: -210.67368152468887
# Steepness: -0.21825538597435318
# Step length: 189.7731985885711
#
# Iteration 1
# Objective: -252.09270423022502
# Steepness: -0.18371391068650592
# Step length: 1.963608429927639
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -314.12747011925705
# Steepness: -0.0009361522933707587
# Step length: 67.18252920977856
# Total time for steepest-descent scheme: 0.17183542251586914
#
# Solution for boeing2 using steepest-descent augmentation:
#
# Optimal objective: -315.01880893320003
# Total solve time: 0.17183542251586914
# Number of iterations: 54
# First simplex iterations 273.0
# Average num simplex iterations 15.309090909090909
# Total simplex iterations: 842.0
# First solve time 0.015623092651367188
# Average solve time 0.001420107754794034
# Total solve time: 0.07810592651367188
#
#
#
# Working on problem 12 of 79: netlib_lp_subset\bore3d
# Reading netlib_lp_subset\bore3d...
# Building polyhedron...
# Problem size: n = 315,  m_B = 344,  m_A = 215
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1373.080394208493
# Total solve time: 0.0
# Number of iterations: 50.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.1405932903289795
#
# Iteration 0
# Objective: 47483.69385383171
# Steepness: -65.70256647058822
# Step length: 55.10885274207873
#
# Iteration 1
# Objective: 43862.90079342743
# Steepness: -5.609429770571783
# Step length: 295.8725622557921
# Total time for steepest-descent scheme: 0.10934948921203613
#
# Solution for bore3d using steepest-descent augmentation:
#
# Optimal objective: 1373.080394208492
# Total solve time: 0.10934948921203613
# Number of iterations: 28
# First simplex iterations 71.0
# Average num simplex iterations 30.20689655172414
# Total simplex iterations: 876.0
# First solve time 0.0
# Average solve time 0.0010761392527613147
# Total solve time: 0.031208038330078125
#
#
#
# Working on problem 13 of 79: netlib_lp_subset\brandy
# Reading netlib_lp_subset\brandy...
# removing redundant constraint '10178A'
# removing redundant constraint '10179A'
# removing redundant constraint '10180A'
# removing redundant constraint '10181A'
# removing redundant constraint '10182A'
# removing redundant constraint '10184A'
# removing redundant constraint '10185A'
# removing redundant constraint '10186A'
# removing redundant constraint '10187A'
# removing redundant constraint '10188A'
# removing redundant constraint '10189A'
# removing redundant constraint '10002A'
# removing redundant constraint '10003A'
# removing redundant constraint '10004A'
# removing redundant constraint '10067A'
# removing redundant constraint '10077A'
# removing redundant constraint '10079A'
# removing redundant constraint '10088A'
# removing redundant constraint '10099A'
# removing redundant constraint '10103A'
# removing redundant constraint '10109A'
# removing redundant constraint '10111A'
# removing redundant constraint '10112A'
# removing redundant constraint '10113A'
# removing redundant constraint '10114A'
# removing redundant constraint '10115A'
# removing redundant constraint '10155A'
# removing redundant constraint '10157A'
# removing redundant constraint '10161A'
# removing redundant constraint '10165A'
# removing redundant constraint '10166A'
# removing redundant constraint '10174A'
# removing redundant constraint '10205A'
# removing redundant constraint '10206A'
# removing redundant constraint '10212A'
# removing redundant constraint '10213A'
# removing redundant constraint '10214A'
# removing redundant constraint '10221A'
# Building polyhedron...
# Problem size: n = 249,  m_B = 292,  m_A = 139
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1518.5098964881277
# Total solve time: 0.0
# Number of iterations: 168.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.12497234344482422
#
# Iteration 0
# Objective: 7367.6442998509865
# Steepness: -0.9569586018293144
# Step length: 248.24193327587344
#
# Iteration 1
# Objective: 7130.0870464679
# Steepness: -0.9497841181125869
# Step length: 312.7229820666727
#
# Iteration 50
# Objective: 2209.3273362160603
# Steepness: -0.36313601735627327
# Step length: 5.0721520092019805
#
# Iteration 100
# Objective: 1550.383337637534
# Steepness: -0.07143174072468662
# Step length: 32.96790979045352
#
# Iteration 150
# Objective: 1521.707290837407
# Steepness: -0.006223830727835341
# Step length: 6.891662769990735
# Total time for steepest-descent scheme: 0.5155043601989746
#
# Solution for brandy using steepest-descent augmentation:
#
# Optimal objective: 1518.509896488126
# Total solve time: 0.5155043601989746
# Number of iterations: 182
# First simplex iterations 240.0
# Average num simplex iterations 22.74863387978142
# Total simplex iterations: 4163.0
# First solve time 0.015619277954101562
# Average solve time 0.001280425024814293
# Total solve time: 0.23431777954101562
#
#
#
# Working on problem 14 of 79: netlib_lp_subset\capri
# Reading netlib_lp_subset\capri...
# Building polyhedron...
# Problem size: n = 353,  m_B = 583,  m_A = 158
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 2690.0129137681597
# Total solve time: 0.0
# Number of iterations: 135.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.2655625343322754
#
# Iteration 0
# Objective: 5328.851249969662
# Steepness: -1.3053567196652691
# Step length: 44.314980707825846
#
# Iteration 1
# Objective: 5271.004392120864
# Steepness: -1.2570121318172447
# Step length: 8.879674951765603
#
# Iteration 50
# Objective: 3532.1226139697046
# Steepness: -0.2338257568551899
# Step length: 30.853288203852546
#
# Iteration 100
# Objective: 3330.810593167885
# Steepness: -0.04369605052924816
# Step length: 15.62223078305619
#
# Iteration 150
# Objective: 2967.9617604324767
# Steepness: -0.010223489510348287
# Step length: 1694.0933646572319
#
# Iteration 200
# Objective: 2816.6516569899177
# Steepness: -0.0028567111347154645
# Step length: 361.09413196020995
# Total time for steepest-descent scheme: 0.9685268402099609
#
# Solution for capri using steepest-descent augmentation:
#
# Optimal objective: 2690.012913757962
# Total solve time: 0.9685268402099609
# Number of iterations: 224
# First simplex iterations 339.0
# Average num simplex iterations 17.573333333333334
# Total simplex iterations: 3954.0
# First solve time 0.015623092651367188
# Average solve time 0.0013885413275824654
# Total solve time: 0.3124217987060547
#
#
#
# Working on problem 15 of 79: netlib_lp_subset\cre-c
# Reading netlib_lp_subset\cre-c...
# removing redundant constraint 'BB013'
# removing redundant constraint 'BB023'
# removing redundant constraint 'BB031'
# removing redundant constraint 'BB032'
# removing redundant constraint 'BB033'
# removing redundant constraint 'BB034'
# removing redundant constraint 'BB035'
# removing redundant constraint 'BB043'
# removing redundant constraint 'BB053'
# removing redundant constraint 'BB063'
# removing redundant constraint 'BB073'
# removing redundant constraint 'BB083'
# removing redundant constraint 'BB093'
# removing redundant constraint 'BB123'
# removing redundant constraint 'BB133'
# removing redundant constraint 'BB141'
# removing redundant constraint 'BB142'
# removing redundant constraint 'BB143'
# removing redundant constraint 'BB144'
# removing redundant constraint 'BB145'
# removing redundant constraint 'BB163'
# removing redundant constraint 'BB173'
# removing redundant constraint 'BB213'
# removing redundant constraint 'BB231'
# removing redundant constraint 'BB232'
# removing redundant constraint 'BB233'
# removing redundant constraint 'BB234'
# removing redundant constraint 'BB235'
# removing redundant constraint 'BB303'
# removing redundant constraint 'BB384'
# removing redundant constraint 'BB414'
# removing redundant constraint 'BB424'
# removing redundant constraint 'BB434'
# removing redundant constraint 'BB444'
# removing redundant constraint 'BB454'
# removing redundant constraint 'BB484'
# removing redundant constraint 'BB551'
# removing redundant constraint 'BB552'
# removing redundant constraint 'BB553'
# removing redundant constraint 'BB554'
# removing redundant constraint 'BB555'
# removing redundant constraint 'BB571'
# removing redundant constraint 'BB572'
# removing redundant constraint 'BB573'
# removing redundant constraint 'BB574'
# removing redundant constraint 'BB575'
# removing redundant constraint 'BB584'
# removing redundant constraint 'BB601'
# removing redundant constraint 'BB602'
# removing redundant constraint 'BB603'
# removing redundant constraint 'BB604'
# removing redundant constraint 'BB605'
# removing redundant constraint 'BB611'
# removing redundant constraint 'BB612'
# removing redundant constraint 'BB613'
# removing redundant constraint 'BB614'
# removing redundant constraint 'BB615'
# removing redundant constraint 'BB621'
# removing redundant constraint 'BB622'
# removing redundant constraint 'BB623'
# removing redundant constraint 'BB624'
# removing redundant constraint 'BB625'
# removing redundant constraint 'BB641'
# removing redundant constraint 'BB642'
# removing redundant constraint 'BB643'
# removing redundant constraint 'BB644'
# removing redundant constraint 'BB645'
# removing redundant constraint 'BB651'
# removing redundant constraint 'BB652'
# removing redundant constraint 'BB653'
# removing redundant constraint 'BB654'
# removing redundant constraint 'BB655'
# removing redundant constraint 'BB661'
# removing redundant constraint 'BB662'
# removing redundant constraint 'BB663'
# removing redundant constraint 'BB664'
# removing redundant constraint 'BB665'
# removing redundant constraint 'BB671'
# removing redundant constraint 'BB672'
# removing redundant constraint 'BB673'
# removing redundant constraint 'BB674'
# removing redundant constraint 'BB675'
# Building polyhedron...
# Problem size: n = 3678,  m_B = 6411,  m_A = 253
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 25275116.14088022
# Total solve time: 0.1874549388885498
# Number of iterations: 3012.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 16.157904386520386
#
# Iteration 0
# Objective: 32664046.084580224
# Steepness: -335.9113380714124
# Step length: 188.15798728857393
#
# Iteration 1
# Objective: 32600841.683301296
# Steepness: -304.7555349113966
# Step length: 164.51070462020806
#
# Iteration 50
# Objective: 29473930.514197547
# Steepness: -134.34821755757287
# Step length: 17.186542490643294
#
# Iteration 100
# Objective: 27484258.804364644
# Steepness: -97.47053978362135
# Step length: 67.26760603718485
#
# Iteration 150
# Objective: 26905388.024503455
# Steepness: -64.9884302623024
# Step length: 600.8818207632337
#
# Iteration 200
# Objective: 26113147.837880705
# Steepness: -58.666666666666664
# Step length: 232.80000000000004
#
# Iteration 250
# Objective: 25536330.292165674
# Steepness: -44.0
# Step length: 125.51147953135239
#
# Iteration 300
# Objective: 25388840.865787312
# Steepness: -18.62751777000832
# Step length: 86.6474501097524
#
# Iteration 350
# Objective: 25328237.071472324
# Steepness: -9.028225536791549
# Step length: 5.627681615889594
#
# Iteration 400
# Objective: 25285162.313604653
# Steepness: -1.7442283146820223
# Step length: 270.3625746588374
# Total time for steepest-descent scheme: 21.210330963134766
#
# Solution for cre-c using steepest-descent augmentation:
#
# Optimal objective: 25275116.140880216
# Total solve time: 21.210330963134766
# Number of iterations: 443
# First simplex iterations 3273.0
# Average num simplex iterations 36.513513513513516
# Total simplex iterations: 16212.0
# First solve time 0.2499408721923828
# Average solve time 0.017472211305085604
# Total solve time: 7.757661819458008
#
#
#
# Working on problem 16 of 79: netlib_lp_subset\cycle
# Reading netlib_lp_subset\cycle...
# removing redundant constraint 'GHF...EB'
# removing redundant constraint 'GHH...EB'
# removing redundant constraint 'GHT...EB'
# removing redundant constraint 'GHX...EB'
# removing redundant constraint 'BGL...AA'
# removing redundant constraint 'BGL...AC'
# removing redundant constraint 'BOA...AC'
# removing redundant constraint 'BOB...AC'
# removing redundant constraint 'BGL...AE'
# removing redundant constraint 'BOA...AE'
# removing redundant constraint 'BOF...BD'
# removing redundant constraint 'BGL...CF'
# removing redundant constraint 'BOB...CF'
# removing redundant constraint 'BOX...CF'
# removing redundant constraint 'BGL...DD'
# removing redundant constraint 'BDN...EF'
# removing redundant constraint 'BOB...EF'
# Building polyhedron...
# Problem size: n = 2857,  m_B = 3437,  m_A = 1376
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -5.226393024894103
# Total solve time: 0.07810759544372559
# Number of iterations: 1249.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 8.54653286933899
#
# Iteration 0
# Objective: 0.0
# Steepness: -0.002044842246139126
# Step length: 696.8753469118344
#
# Iteration 1
# Objective: -1.425000149658178
# Steepness: -0.0018861745610514319
# Step length: 641.0281747197395
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: -4.6147175402893845
# Steepness: -5.8045906627586405e-05
# Step length: 0.04203369500352482
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: -4.7190719804749355
# Steepness: -2.24458408267981e-05
# Step length: 7.03310334215786
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: -4.80036780975365
# Steepness: -2.003191531256712e-05
# Step length: 0.20336371026612332
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 200
# Objective: -4.860184488069124
# Steepness: -1.4417410967291198e-05
# Step length: 17.849394271735427
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 250
# Objective: -4.862267343297772
# Steepness: -1.1202721038087498e-05
# Step length: 48.57360587639151
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 300
# Objective: -5.105119790452807
# Steepness: -6.922865600467035e-06
# Step length: 6.157494214165707e-08
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 350
# Objective: -5.224935700452923
# Steepness: -2.186825072475013e-06
# Step length: 4.5443474738740835e-07
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 400
# Objective: -5.224909844176861
# Steepness: -1.8887635473168662e-06
# Step length: 12.002337791811568
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 12.832705974578857
#
# Solution for cycle using steepest-descent augmentation:
#
# Optimal objective: -5.224935885986631
# Total solve time: 12.832705974578857
# Number of iterations: 404
# First simplex iterations 913.0
# Average num simplex iterations 39.94567901234568
# Total simplex iterations: 16178.0
# First solve time 0.06252288818359375
# Average solve time 0.014720954424069252
# Total solve time: 5.961986541748047
# Working on problem 17 of 79: netlib_lp_subset\degen2
# Reading netlib_lp_subset\degen2...
# Building polyhedron...
# Problem size: n = 534,  m_B = 757,  m_A = 221
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -1435.178
# Total solve time: 0.031235694885253906
# Number of iterations: 443.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.3905339241027832
#
# Iteration 0
# Objective: -1306.9044827586206
# Steepness: -1.7925
# Step length: 6.0
#
# Iteration 1
# Objective: -1317.6594827586205
# Steepness: -1.7718749999999999
# Step length: 8.0
#
# Iteration 50
# Objective: -1429.8059895457757
# Steepness: -0.1772289156626507
# Step length: 2.042161892960703
# Total time for steepest-descent scheme: 0.4686415195465088
#
# Solution for degen2 using steepest-descent augmentation:
#
# Optimal objective: -1435.1779999999999
# Total solve time: 0.4686415195465088
# Number of iterations: 79
# First simplex iterations 362.0
# Average num simplex iterations 25.525
# Total simplex iterations: 2042.0
# First solve time 0.015625
# Average solve time 0.0025384902954101564
# Total solve time: 0.2030792236328125
#
#
#
# Working on problem 18 of 79: netlib_lp_subset\degen3
# Reading netlib_lp_subset\degen3...
# Building polyhedron...
# Problem size: n = 1818,  m_B = 2604,  m_A = 717
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -987.2940000000006
# Total solve time: 0.24994158744812012
# Number of iterations: 1837.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 3.897392749786377
#
# Iteration 0
# Objective: -932.4849999999999
# Steepness: -0.24392857142857138
# Step length: 14.0
#
# Iteration 1
# Objective: -935.9
# Steepness: -0.18750000000000053
# Step length: 7.999999999999993
#
# Iteration 50
# Objective: -978.753375587565
# Steepness: -0.046749999999999986
# Step length: 11.128125000000553
#
# Iteration 100
# Objective: -986.6566362859694
# Steepness: -0.016000000000000014
# Step length: 4.605989339707497
# Total time for steepest-descent scheme: 3.9365482330322266
#
# Solution for degen3 using steepest-descent augmentation:
#
# Optimal objective: -987.294
# Total solve time: 3.9365482330322266
# Number of iterations: 144
# First simplex iterations 2093.0
# Average num simplex iterations 50.827586206896555
# Total simplex iterations: 7370.0
# First solve time 0.21866607666015625
# Average solve time 0.014865375387257544
# Total solve time: 2.1554794311523438
#
#
#
# Working on problem 19 of 79: netlib_lp_subset\e226
# Reading netlib_lp_subset\e226...
# Building polyhedron...
# Problem size: n = 282,  m_B = 472,  m_A = 33
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -18.751929066370515
# Total solve time: 0.01562047004699707
# Number of iterations: 314.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.12497067451477051
#
# Iteration 0
# Objective: 46.399449185733985
# Steepness: -1.3398333333333332
# Step length: 1.9032
#
# Iteration 1
# Objective: 43.84947838573398
# Steepness: -1.2733999999999999
# Step length: 1.4071147426927355
#
# Iteration 50
# Objective: 9.453259080752005
# Steepness: -0.14160756902814753
# Step length: 0.2921041376015669
#
# Iteration 100
# Objective: -7.4471185567744165
# Steepness: -0.056931416214933125
# Step length: 2.04174711251281
#
# Iteration 150
# Objective: -13.668447287517813
# Steepness: -0.021272682507592868
# Step length: 50.13242303753244
#
# Iteration 200
# Objective: -18.467259432495304
# Steepness: -0.0020492335119966787
# Step length: 0.22953238512346497
# Total time for steepest-descent scheme: 0.8294367790222168
#
# Solution for e226 using steepest-descent augmentation:
#
# Optimal objective: -18.75192908773188
# Total solve time: 0.8294367790222168
# Number of iterations: 245
# First simplex iterations 170.0
# Average num simplex iterations 16.95528455284553
# Total simplex iterations: 4171.0
# First solve time 0.015623092651367188
# Average solve time 0.0012065375723489902
# Total solve time: 0.29680824279785156
#
#
#
# Working on problem 20 of 79: netlib_lp_subset\etamacro
# Reading netlib_lp_subset\etamacro...
# Building polyhedron...
# Problem size: n = 688,  m_B = 869,  m_A = 354
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -755.715227180067
# Total solve time: 0.015655040740966797
# Number of iterations: 419.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.687305212020874
#
# Iteration 0
# Objective: 258.7190233697028
# Steepness: -141.74356363636363
# Step length: 2.6795400805555554
#
# Iteration 1
# Objective: -121.08853655471052
# Steepness: -118.8062705420267
# Step length: 0.07979418599999968
#
# Iteration 50
# Objective: -744.6203413948422
# Steepness: -0.01976213902743142
# Step length: 27.234211850038108
#
# Iteration 100
# Objective: -753.1547469380167
# Steepness: -0.005874756962861641
# Step length: 61.873743561997735
#
# Iteration 150
# Objective: -755.2693341084193
# Steepness: -0.00105933045131846
# Step length: 81.14185385206389
# Total time for steepest-descent scheme: 1.1835229396820068
#
# Solution for etamacro using steepest-descent augmentation:
#
# Optimal objective: -755.7152304387405
# Total solve time: 1.1835229396820068
# Number of iterations: 195
# First simplex iterations 344.0
# Average num simplex iterations 18.46938775510204
# Total simplex iterations: 3620.0
# First solve time 0.015661239624023438
# Average solve time 0.002342477136728715
# Total solve time: 0.4591255187988281
#
#
#
# Working on problem 21 of 79: netlib_lp_subset\fffff800
# Reading netlib_lp_subset\fffff800...
# Building polyhedron...
# Problem size: n = 854,  m_B = 1028,  m_A = 350
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 555679.5648174963
# Total solve time: 0.015622615814208984
# Number of iterations: 200.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.8591394424438477
#
# Iteration 0
# Objective: 1114766.2334283995
# Steepness: -0.4729057534642362
# Step length: 164700.0706206992
#
# Iteration 1
# Objective: 1036878.6224359048
# Steepness: -0.4725108682881596
# Step length: 494738.6570442258
# Degenerate step computed. Changing active facets...
#
# Iteration 50
# Objective: 594012.5735869347
# Steepness: -0.21120976271916025
# Step length: 5312.278535254812
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: 559209.2321164267
# Steepness: -0.033597890672723826
# Step length: 94.63925001438749
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
#
# Iteration 150
# Objective: 555727.6501070036
# Steepness: -0.0011874835516602414
# Step length: 0.0058881743201273755
# Total time for steepest-descent scheme: 1.1644062995910645
#
# Solution for fffff800 using steepest-descent augmentation:
#
# Optimal objective: 555679.5174914981
# Total solve time: 1.1644062995910645
# Number of iterations: 176
# First simplex iterations 291.0
# Average num simplex iterations 14.282485875706215
# Total simplex iterations: 2528.0
# First solve time 0.015623092651367188
# Average solve time 0.0018267550710904395
# Total solve time: 0.3233356475830078
#
#
#
# Working on problem 22 of 79: netlib_lp_subset\finnis
# Reading netlib_lp_subset\finnis...
# Building polyhedron...
# Problem size: n = 614,  m_B = 1055,  m_A = 92
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 172791.0655956116
# Total solve time: 0.0
# Number of iterations: 367.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.531125545501709
#
# Iteration 0
# Objective: 798939.0691258578
# Steepness: -16.242374640951986
# Step length: 236.10533633440514
#
# Iteration 1
# Objective: 795104.1577983864
# Steepness: -13.997324983392597
# Step length: 536.2642109949455
#
# Iteration 50
# Objective: 605174.1296880627
# Steepness: -6.180947981663575
# Step length: 595.0236429997466
#
# Iteration 100
# Objective: 323874.38171495806
# Steepness: -1.9823730368114378
# Step length: 0.00015778735464309159
#
# Iteration 150
# Objective: 178721.979599374
# Steepness: -0.5961919750590499
# Step length: 19.108801507288714
# Total time for steepest-descent scheme: 1.1091487407684326
#
# Solution for finnis using steepest-descent augmentation:
#
# Optimal objective: 172791.066231562
# Total solve time: 1.1091487407684326
# Number of iterations: 179
# First simplex iterations 199.0
# Average num simplex iterations 9.677777777777777
# Total simplex iterations: 1742.0
# First solve time 0.0
# Average solve time 0.0013891114128960504
# Total solve time: 0.25004005432128906
#
#
#
# Working on problem 23 of 79: netlib_lp_subset\fit1d
# Reading netlib_lp_subset\fit1d...
# Building polyhedron...
# Problem size: n = 1026,  m_B = 2075,  m_A = 1
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -9146.378092420928
# Total solve time: 0.09375929832458496
# Number of iterations: 1721.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 1.665959119796753
#
# Iteration 0
# Objective: 41580.0
# Steepness: -169.82146083123405
# Step length: 11.956533855741208
#
# Iteration 1
# Objective: 39549.52395413992
# Steepness: -163.66197462238017
# Step length: 4.048745770762011
#
# Iteration 50
# Objective: 19014.280698512845
# Steepness: -76.90610931000965
# Step length: 0.41234357233155405
#
# Iteration 100
# Objective: 8304.403359432725
# Steepness: -51.88354460987622
# Step length: 0.5318862858019574
#
# Iteration 150
# Objective: 1792.2519062720862
# Steepness: -32.82394047194345
# Step length: 5.454137075761758
#
# Iteration 200
# Objective: -2153.5172030027857
# Steepness: -22.58060998596867
# Step length: 3.85850928279084
#
# Iteration 250
# Objective: -4476.711266085429
# Steepness: -17.87768611544124
# Step length: 0.12791518052193115
#
# Iteration 300
# Objective: -6407.327409330619
# Steepness: -10.559983556642086
# Step length: 1.0152644177945385
#
# Iteration 350
# Objective: -7350.316915481797
# Steepness: -7.064690040786022
# Step length: 0.5475484490264938
#
# Iteration 400
# Objective: -8195.910472697324
# Steepness: -4.689344055383421
# Step length: 0.70743864427814
#
# Iteration 450
# Objective: -8558.066232463345
# Steepness: -2.826650241266844
# Step length: 0.9427611653483833
#
# Iteration 500
# Objective: -8788.73234795672
# Steepness: -1.6406801638561759
# Step length: 0.16780139979659667
#
# Iteration 550
# Objective: -8917.665010821516
# Steepness: -0.5128489559969741
# Step length: 0.4346340406481715
#
# Iteration 600
# Objective: -9030.091555620898
# Steepness: -0.07187672246541033
# Step length: 2.297140604007044
#
# Iteration 650
# Objective: -9127.916109008289
# Steepness: -0.009485708682985938
# Step length: 30.07305806860291
# Total time for steepest-descent scheme: 7.8501410484313965
#
# Solution for fit1d using steepest-descent augmentation:
#
# Optimal objective: -9146.378092420926
# Total solve time: 7.8501410484313965
# Number of iterations: 682
# First simplex iterations 242.0
# Average num simplex iterations 16.323572474377745
# Total simplex iterations: 11149.0
# First solve time 0.04488182067871094
# Average solve time 0.0027876752012819706
# Total solve time: 1.903982162475586
#
#
#
# Working on problem 24 of 79: netlib_lp_subset\fit1p
# Reading netlib_lp_subset\fit1p...
# Building polyhedron...
# Problem size: n = 1677,  m_B = 2076,  m_A = 627
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 9146.378092420935
# Total solve time: 0.06252646446228027
# Number of iterations: 1018.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 2.888814926147461
#
# Iteration 0
# Objective: 10378.5
# Steepness: -0.29500322514365257
# Step length: 1039.215047222461
#
# Iteration 1
# Objective: 10071.92820945156
# Steepness: -0.288218566486953
# Step length: 92.94624259472782
#
# Iteration 50
# Objective: 9738.758049552762
# ...
# Building polyhedron...
# Problem size: n = 2036,  m_B = 4731,  m_A = 548
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 15394362.183631927
# Total solve time: 0.0
# Number of iterations: 242.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 6.530644416809082
#
# Iteration 0
# Objective: 18969945.54860455
# Steepness: -697.1957453616976
# Step length: 100.80067199999998
#
# Iteration 1
# Objective: 18899667.74895655
# Steepness: -329.55071632855766
# Step length: 67.200448
#
# Iteration 50
# Objective: 16706552.99989001
# Steepness: -18.881208291944723
# Step length: 67.20044800000002
# Degenerate step computed. Changing active facets...
#
# Iteration 100
# Objective: 16103729.531332318
# Steepness: -3.092011206896547
# Step length: 2210.6699999999987
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 3.389826774597168
#
# Solution for sierra using steepest-descent augmentation:
#
# Optimal objective: 15394362.183631929
# Total solve time: 3.389826774597168
# Number of iterations: 143
# First simplex iterations 2463.0
# Average num simplex iterations 25.493055555555557
# Total simplex iterations: 3671.0
# First solve time 0.07806777954101562
# Average solve time 0.004663493898179796
# Total solve time: 0.6715431213378906
#
#
#
# Working on problem 71 of 79: netlib_lp_subset\stair
# Reading netlib_lp_subset\stair...
# Building polyhedron...
# Problem size: n = 467,  m_B = 532,  m_A = 291
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -251.26695119296252
# Total solve time: 0.015619993209838867
# Number of iterations: 129.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.2967720031738281
#
# Iteration 0
# Objective: -208.79999
# Steepness: -0.005592475513803438
# Step length: 9.82468413580425
#
# Iteration 1
# Objective: -208.85493430546035
# Steepness: -0.005477029732576367
# Step length: 65.13452251915945
#
# Iteration 50
# Objective: -239.84617414489685
# Steepness: -0.004272611343238764
# Step length: 258.5572984549362
#
# Iteration 100
# Objective: -248.678342512655
# Steepness: -0.0028291539147907675
# Step length: 7.4664019714637595
# Total time for steepest-descent scheme: 0.7264015674591064
#
# Solution for stair using steepest-descent augmentation:
#
# Optimal objective: -251.26695119296363
# Total solve time: 0.7264015674591064
# Number of iterations: 137
# First simplex iterations 553.0
# Average num simplex iterations 23.52173913043478
# Total simplex iterations: 3246.0
# First solve time 0.031244277954101562
# Average solve time 0.0029614628225133038
# Total solve time: 0.40868186950683594
#
#
#
# Working on problem 72 of 79: netlib_lp_subset\standata
# Reading netlib_lp_subset\standata...
# Building polyhedron...
# Problem size: n = 1075,  m_B = 1362,  m_A = 176
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1257.6995
# Total solve time: 0.0
# Number of iterations: 139.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 1.1247727870941162
#
# Iteration 0
# Objective: 78034.4695
# Steepness: -0.9031476997578692
# Step length: 7310.099999999999
#
# Iteration 1
# Objective: 71432.3695
# Steepness: -0.9031476997578692
# Step length: 7310.099999999999
# Total time for steepest-descent scheme: 0.37109827995300293
#
# Solution for standata using steepest-descent augmentation:
#
# Optimal objective: 1257.699499999989
# Total solve time: 0.37109827995300293
# Number of iterations: 43
# First simplex iterations 298.0
# Average num simplex iterations 10.068181818181818
# Total simplex iterations: 443.0
# First solve time 0.0
# Average solve time 0.0013854286887428977
# Total solve time: 0.0609588623046875
#
#
#
# Working on problem 73 of 79: netlib_lp_subset\standgub
# Reading netlib_lp_subset\standgub...
# Building polyhedron...
# Problem size: n = 1184,  m_B = 1471,  m_A = 178
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1257.6995
# Total solve time: 0.0
# Number of iterations: 137.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 1.2440626621246338
#
# Iteration 0
# Objective: 78030.9695
# Steepness: -0.9031476997578692
# Step length: 7310.099999999999
#
# Iteration 1
# Objective: 71428.8695
# Steepness: -0.9031476997578692
# Step length: 7310.099999999999
# Total time for steepest-descent scheme: 0.3603341579437256
#
# Solution for standgub using steepest-descent augmentation:
#
# Optimal objective: 1257.699499999989
# Total solve time: 0.3603341579437256
# Number of iterations: 42
# First simplex iterations 396.0
# Average num simplex iterations 13.674418604651162
# Total simplex iterations: 588.0
# First solve time 0.015123367309570312
# Average solve time 0.002172603163608285
# Total solve time: 0.09342193603515625
#
#
#
# Working on problem 74 of 79: netlib_lp_subset\standmps
# Reading netlib_lp_subset\standmps...
# Building polyhedron...
# Problem size: n = 1075,  m_B = 1362,  m_A = 284
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1406.0175
# Total solve time: 0.0
# Number of iterations: 60.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 1.140512466430664
#
# Iteration 0
# Objective: 1431.7825
# Steepness: -0.48881789137380194
# Step length: 1.5650000000000084
#
# Iteration 1
# Objective: 1431.0175
# Steepness: -0.38461538461538464
# Step length: 65.0
# Total time for steepest-descent scheme: 0.03559088706970215
#
# Solution for standmps using steepest-descent augmentation:
#
# Optimal objective: 1406.0175
# Total solve time: 0.03559088706970215
# Number of iterations: 2
# First simplex iterations 393.0
# Average num simplex iterations 154.33333333333334
# Total simplex iterations: 463.0
# First solve time 0.014923095703125
# Average solve time 0.0068683624267578125
# Total solve time: 0.020605087280273438
#
#
#
# Working on problem 75 of 79: netlib_lp_subset\stocfor1
# Reading netlib_lp_subset\stocfor1...
# Building polyhedron...
# Problem size: n = 111,  m_B = 165,  m_A = 63
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -41131.976219436416
# Total solve time: 0.000997781753540039
# Number of iterations: 30.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.029922008514404297
#
# Iteration 0
# Objective: 1138617.5351493538
# Steepness: -14.375057715400349
# Step length: 1246.2586484649157
#
# Iteration 1
# Objective: 1120702.4951493538
# Steepness: -14.37364630328653
# Step length: 56800.568229963654
# Total time for steepest-descent scheme: 0.028919696807861328
#
# Solution for stocfor1 using steepest-descent augmentation:
#
# Optimal objective: -41131.97621943613
# Total solve time: 0.028919696807861328
# Number of iterations: 16
# First simplex iterations 76.0
# Average num simplex iterations 11.176470588235293
# Total simplex iterations: 190.0
# First solve time 0.001995086669921875
# Average solve time 0.000467076021082261
# Total solve time: 0.007940292358398438
#
#
#
# Working on problem 76 of 79: netlib_lp_subset\stocfor2
# Reading netlib_lp_subset\stocfor2...
# Building polyhedron...
# Problem size: n = 2031,  m_B = 3045,  m_A = 1143
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: -39024.408537882126
# Total solve time: 0.046863555908203125
# Number of iterations: 820.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 5.0791473388671875
#
# Iteration 0
# Objective: 1149061.3192775468
# Steepness: -7.395799693662501
# Step length: 112949.16404423292
#
# Iteration 1
# Objective: 313711.9264397748
# Steepness: -7.364278412176154
# Step length: 5016.070002169782
#
# Iteration 50
# Objective: -35312.66326457486
# Steepness: -0.027195150971908694
# Step length: 189.6082374588593
#
# Iteration 100
# Objective: -36426.220910266675
# Steepness: -0.026618747323245127
# Step length: 163.04333108791135
#
# Iteration 150
# Objective: -37240.87085892288
# Steepness: -0.025799534400633695
# Step length: 443.439845307014
#
# Iteration 200
# Objective: -37873.6071331104
# Steepness: -0.023548670608364658
# Step length: 608.751767706244
#
# Iteration 250
# Objective: -38457.613302475154
# Steepness: -0.015680589539765664
# Step length: 442.6536612137709
#
# Iteration 300
# Objective: -38880.57772134185
# Steepness: -0.009210000799766777
# Step length: 174.4335685619627
#
# Iteration 350
# Objective: -39023.59795581704
# Steepness: -0.0004348545109761204
# Step length: 469.0419640355532
# Total time for steepest-descent scheme: 6.717971563339233
#
# Solution for stocfor2 using steepest-descent augmentation:
#
# Optimal objective: -39024.40853788161
# Total solve time: 6.717971563339233
# Number of iterations: 356
# First simplex iterations 1414.0
# Average num simplex iterations 15.92436974789916
# Total simplex iterations: 5685.0
# First solve time 0.04686164855957031
# Average solve time 0.005473572332985929
# Total solve time: 1.9540653228759766
#
#
#
# Working on problem 77 of 79: netlib_lp_subset\tuff
# Reading netlib_lp_subset\tuff...
# removing redundant constraint 'GOI...BW'
# removing redundant constraint 'NOI.G0BW'
# removing redundant constraint 'NOI.G1BW'
# removing redundant constraint 'NOI.G3BW'
# removing redundant constraint 'NOI.G5BW'
# removing redundant constraint 'NOI.G6BW'
# removing redundant constraint 'NOI.G7BW'
# removing redundant constraint 'NOI.G9BW'
# removing redundant constraint 'BBI...BW'
# removing redundant constraint 'BXV...BW'
# removing redundant constraint 'BXW...BW'
# removing redundant constraint 'BXZ...BW'
# removing redundant constraint 'BX5...BW'
# removing redundant constraint 'B3A...BW'
# removing redundant constraint 'B3B...BW'
# removing redundant constraint 'B3C...BW'
# removing redundant constraint 'B3D...BW'
# removing redundant constraint 'B3G...BW'
# removing redundant constraint 'B3H...BW'
# removing redundant constraint 'B3I...BW'
# removing redundant constraint 'B3J...BW'
# removing redundant constraint 'B3K...BW'
# removing redundant constraint 'B3L...BW'
# removing redundant constraint 'B3M...BW'
# removing redundant constraint 'B3N...BW'
# removing redundant constraint 'B3O...BW'
# removing redundant constraint 'B4A...BW'
# removing redundant constraint 'B4B...BW'
# removing redundant constraint 'B4C...BW'
# removing redundant constraint 'B4D...BW'
# removing redundant constraint 'B4G...BW'
# removing redundant constraint 'B4H...BW'
# removing redundant constraint 'B4I...BW'
# removing redundant constraint 'B4J...BW'
# removing redundant constraint 'B4K...BW'
# removing redundant constraint 'B4L...BW'
# removing redundant constraint 'B4M...BW'
# removing redundant constraint 'B4N...BW'
# removing redundant constraint 'B4O...BW'
# Building polyhedron...
# Problem size: n = 587,  m_B = 641,  m_A = 264
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 0.29214776509361323
# Total solve time: 0.003988981246948242
# Number of iterations: 96.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.38497209548950195
#
# Iteration 0
# Objective: 0.3290396238741178
# Steepness: -9.256850058763296e-06
# Step length: 1.6682781868299554
#
# Iteration 1
# Objective: 0.329024180873086
# Steepness: -9.042114959805438e-06
# Step length: 0.004285651122216497
#
# Iteration 50
# Objective: 0.31668634250685435
# Steepness: -7.036187281436319e-06
# Step length: 98.67158307629272
#
# Iteration 100
# Objective: 0.2942369716408881
# Steepness: -3.0007995307588444e-06
# Step length: 25.760761062968463
# Total time for steepest-descent scheme: 0.7527759075164795
#
# Solution for tuff using steepest-descent augmentation:
#
# Optimal objective: 0.29214776509361284
# Total solve time: 0.7527759075164795
# Number of iterations: 133
# First simplex iterations 606.0
# Average num simplex iterations 29.58955223880597
# Total simplex iterations: 3965.0
# First solve time 0.021974563598632812
# Average solve time 0.0021648264642971666
# Total solve time: 0.2900867462158203
#
#
#
# Working on problem 78 of 79: netlib_lp_subset\vtp_base
# Reading netlib_lp_subset\vtp_base...
# Building polyhedron...
# Problem size: n = 203,  m_B = 392,  m_A = 73
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 129831.46246136134
# Total solve time: 0.0019943714141845703
# Number of iterations: 70.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 0.0827794075012207
#
# Iteration 0
# Objective: 410564.2879557965
# Steepness: -0.9718834253073354
# Step length: 10669.863
#
# Iteration 1
# Objective: 400194.42495579657
# Steepness: -0.9718834253073354
# Step length: 32009.588999999996
# Total time for steepest-descent scheme: 0.10870933532714844
#
# Solution for vtp_base using steepest-descent augmentation:
#
# Optimal objective: 129831.4624613614
# Total solve time: 0.10870933532714844
# Number of iterations: 34
# First simplex iterations 223.0
# Average num simplex iterations 19.885714285714286
# Total simplex iterations: 696.0
# First solve time 0.00997161865234375
# Average solve time 0.0012820652553013393
# Total solve time: 0.044872283935546875
#
#
#
# Working on problem 79 of 79: netlib_lp_subset\wood1p
# Reading netlib_lp_subset\wood1p...
# Building polyhedron...
# Problem size: n = 2594,  m_B = 2595,  m_A = 243
# Finding feasible solution...
#
# Solving with simplex method...
#
# Solution using simplex method:
#
# Optimal objective: 1.4429024115734086
# Total solve time: 0.031225204467773438
# Number of iterations: 288.0
#
# Solving with steepest descent...
# Building polyhedral model. Solve method: dual_simplex
# Changed value of parameter method to 1
#    Prev: -1  Min: -1  Max: 5  Default: -1
# Polyhedral model built!
# Polyhedral model build time: 4.4725892543792725
#
# Iteration 0
# Objective: 5.243580744090042
# Steepness: -0.7498809019593753
# Step length: 0.030035882141350376
#
# Iteration 1
# Objective: 5.221057409698741
# Steepness: -0.7498785641060166
# Step length: 0.5629054484729589
#
# Iteration 50
# Objective: 2.6243648736260514
# Steepness: -0.6290911506304789
# Step length: 0.016872823802003264
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Degenerate step computed. Changing active facets...
# Total time for steepest-descent scheme: 1.9048724174499512
#
# Solution for wood1p using steepest-descent augmentation:
#
# Optimal objective: 1.4429023978361408
# Total solve time: 1.9048724174499512
# Number of iterations: 100
# First simplex iterations 263.0
# Average num simplex iterations 11.267326732673267
# Total simplex iterations: 1138.0
# First solve time 0.06151771545410156
# Average solve time 0.007413883020382117
# Total solve time: 0.7488021850585938
